# %%
from model import *

# %%
TrainFoodCNN()
# Out:
# [Debug] [Model] Initializing Datasets and Dataloaders...
# [Debug] [Model] Using Batch size of '32'
# [Debug] [Model] Using Learning Rate of '0.001'
# [Debug] [Model] Using num_workers: '2'
# Training the model....
# Epoch 0/14
# ----------
# training Loss: 1.9356 Acc: 0.3844
# validation Loss: 1.5097 Acc: 0.5223
# Epoch duration 0m 51s
#
# Epoch 1/14
# ----------
# training Loss: 1.1875 Acc: 0.6097
# validation Loss: 1.4018 Acc: 0.5580
# Epoch duration 0m 50s
#
# Epoch 2/14
# ----------
# training Loss: 0.9799 Acc: 0.6892
# validation Loss: 1.4190 Acc: 0.5565
# Epoch duration 0m 50s
#
# Epoch 3/14
# ----------
# training Loss: 0.8105 Acc: 0.7283
# validation Loss: 1.1161 Acc: 0.6414
# Epoch duration 0m 51s
#
# Epoch 4/14
# ----------
# training Loss: 0.7210 Acc: 0.7629
# validation Loss: 1.2631 Acc: 0.6027
# Epoch duration 0m 50s
#
# Epoch 5/14
# ----------
# training Loss: 0.6710 Acc: 0.7809
# validation Loss: 1.1327 Acc: 0.6964
# Epoch duration 0m 50s
#
# Epoch 6/14
# ----------
# training Loss: 0.6511 Acc: 0.7960
# validation Loss: 0.8545 Acc: 0.7515
# Epoch duration 0m 51s
#
# Epoch 7/14
# ----------
# training Loss: 0.5342 Acc: 0.8247
# validation Loss: 1.2773 Acc: 0.6994
# Epoch duration 0m 50s
#
# Epoch 8/14
# ----------
# training Loss: 0.5482 Acc: 0.8211
# validation Loss: 1.4609 Acc: 0.6726
# Epoch duration 0m 53s
#
# Epoch 9/14
# ----------
# training Loss: 0.5927 Acc: 0.8144
# validation Loss: 1.0280 Acc: 0.7693
# Epoch duration 0m 52s
#
# Epoch 10/14
# ----------
# training Loss: 0.5311 Acc: 0.8288
# validation Loss: 1.2106 Acc: 0.7440
# Epoch duration 0m 52s
#
# Epoch 11/14
# ----------
# training Loss: 0.5353 Acc: 0.8303
# validation Loss: 1.1195 Acc: 0.7158
# Epoch duration 0m 52s
#
# Epoch 12/14
# ----------
# training Loss: 0.4920 Acc: 0.8420
# validation Loss: 0.9764 Acc: 0.7783
# Epoch duration 0m 51s
#
# Epoch 13/14
# ----------
# training Loss: 0.4335 Acc: 0.8535
# validation Loss: 1.6065 Acc: 0.6845
# Epoch duration 0m 51s
#
# Epoch 14/14
# ----------
# training Loss: 0.4591 Acc: 0.8494
# validation Loss: 1.1918 Acc: 0.7455
# Epoch duration 0m 51s
#
# Training completed in 12m 44s
# Lowest validation loss: 0.854549

# %%
EvaluateOnData(ImageClassModel, "Dataset/test_labels.csv", "Dataset/test2")
# Out:
# [Debug] [Evaluate] Sample Image:
# Accuracy of the model is: 75.1488 %

# %%
SaveCurrentModel("Dataset/Latest.pt")
# Out:
# Saving current model to 'Dataset/Latest.pt'
