# %%
from model import *

# %%
# LoadSavedModel("Dataset/Resnet.pt")

# %%
TrainFoodCNN()
# Out:
# Initializing Datasets and Dataloaders...
# Using Batch size of '32'
# Using weight_decay: '0'
# Using Learning Rate of '0.001'
# Using num_workers: '2'
# Training the model....
# Epoch 0/9
# ----------
# training Loss: 1.5412 Acc: 0.5158
# validation Loss: 1.5845 Acc: 0.5283
# Epoch duration 0m 57s
#
# Epoch 1/9
# ----------
# training Loss: 0.5218 Acc: 0.8314
# validation Loss: 1.6286 Acc: 0.6786
# Epoch duration 0m 58s
#
# Epoch 2/9
# ----------
# training Loss: 0.2946 Acc: 0.8991
# validation Loss: 2.0873 Acc: 0.6071
# Epoch duration 0m 58s
#
# Epoch 3/9
# ----------
# training Loss: 0.2206 Acc: 0.9323
# validation Loss: 1.3484 Acc: 0.7470
# Epoch duration 0m 58s
#
# Epoch 4/9
# ----------
# training Loss: 0.1470 Acc: 0.9543
# validation Loss: 2.1291 Acc: 0.6875
# Epoch duration 0m 57s
#
# Epoch 5/9
# ----------
# training Loss: 0.1036 Acc: 0.9698
# validation Loss: 2.1834 Acc: 0.6890
# Epoch duration 0m 57s
#
# Epoch 6/9
# ----------
# training Loss: 0.1034 Acc: 0.9647
# ...

# %%
EvaluateOnData(ImageClassModel, "Dataset/test_labels.csv", "Dataset/test2")
# Out:
# Sample Image
# Accuracy of the model is: 74.7024 %

# %%
# LoadSavedModel("Dataset/FashionCNN")

# %%
EvaluateOnData(ImageClassModel, "Dataset/real_labels.csv", "Dataset/Upload_Images")
# Out:
# Sample Image
# Accuracy of the model is: 4.6512 %

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
#
# NVIDIA GeForce GTX 1080
# Memory Usage:
# Allocated: 0.1 GB
# Cached:    0.9 GB

# %%
# SaveCurrentModel("Dataset/Latest.pt")
# Out:
# Saving current model to 'Dataset/Latest.pt'

# %%
# LoadLatestModel()
