# %%
from model import *

# %%
TrainFoodCNN()
# Out:
# [Debug] [Model] Initializing Datasets and Dataloaders...
# [Debug] [Model] Using Batch size of '32'
# [Debug] [Model] Using Learning Rate of '0.001'
# [Debug] [Model] Using num_workers: '2'
# Training the model....
# Epoch 0/4
# ----------
# training Loss: 2.1254 Acc: 0.3336
# validation Loss: 1.4052 Acc: 0.4598
# Epoch duration 1m 16s
#
# Epoch 1/4
# ----------
# training Loss: 1.2854 Acc: 0.5714
# validation Loss: 1.2215 Acc: 0.5625
# Epoch duration 0m 52s
#
# Epoch 2/4
# ----------
# training Loss: 1.0327 Acc: 0.6550
# validation Loss: 1.1186 Acc: 0.5491
# Epoch duration 0m 50s
#
# Epoch 3/4
# ----------
# training Loss: 0.8788 Acc: 0.7062
# validation Loss: 0.9821 Acc: 0.6994
# Epoch duration 0m 51s
#
# Epoch 4/4
# ----------
# training Loss: 0.7349 Acc: 0.7596
# validation Loss: 1.1776 Acc: 0.6994
# Epoch duration 0m 53s
#
# Training completed in 4m 42s
# Lowest validation loss: 0.982132

# %%
EvaluateOnData(ImageClassModel, "Dataset/test_labels.csv", "Dataset/test2")
# Out:
# [Debug] [Evaluate] Sample Image:
# Accuracy of the model is: 69.9405 %

# %%
EvaluateOnData(ImageClassModel, "Dataset/real_labels.csv", "Dataset/Upload_Images")
# Out:
# [Debug] [Evaluate] Sample Image:
# Accuracy of the model is: 13.9535 %

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
#
# NVIDIA GeForce GTX 1080
# Memory Usage:
# Allocated: 0.2 GB
# Cached:    1.0 GB

# %%
SaveCurrentModel("Dataset/Latest.pt")
# Out:
# Saving current model to 'Dataset/Latest.pt'

# %%
# LoadLatestModel()
