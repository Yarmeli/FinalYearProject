# %%
from model import *

# %%
TrainFoodCNN()
# Out:
# [Debug] [Model] Initializing Datasets and Dataloaders...
# [Debug] [Model] Using Batch size of '32'
# [Debug] [Model] Using Learning Rate of '0.001'
# [Debug] [Model] Using num_workers: '2'
# Training the model....
# Epoch 0/9
# ----------
# training Loss: 2.7286 Acc: 0.0979
# validation Loss: 2.6423 Acc: 0.1324
# Epoch duration 2m 20s
#
# Epoch 1/9
# ----------
# training Loss: 2.5826 Acc: 0.1219
# validation Loss: 2.4419 Acc: 0.2068
# Epoch duration 0m 53s
#
# Epoch 2/9
# ----------
# training Loss: 2.4792 Acc: 0.1708
# validation Loss: 2.3226 Acc: 0.2976
# Epoch duration 0m 52s
#
# Epoch 3/9
# ----------
# training Loss: 2.3508 Acc: 0.2124
# validation Loss: 2.2406 Acc: 0.2738
# Epoch duration 0m 54s
#
# Epoch 4/9
# ----------
# training Loss: 2.3124 Acc: 0.2342
# validation Loss: 2.2126 Acc: 0.3557
# Epoch duration 0m 52s
#
# Epoch 5/9
# ----------
# training Loss: 2.2499 Acc: 0.2448
# validation Loss: 2.2392 Acc: 0.2902
# Epoch duration 0m 54s
#
# Epoch 6/9
# ----------
# training Loss: 2.2251 Acc: 0.2452
# validation Loss: 2.1349 Acc: 0.3065
# Epoch duration 0m 53s
#
# Epoch 7/9
# ----------
# training Loss: 2.1628 Acc: 0.2610
# validation Loss: 2.0507 Acc: 0.3229
# Epoch duration 0m 54s
#
# Epoch 8/9
# ----------
# training Loss: 2.1823 Acc: 0.2588
# validation Loss: 2.0693 Acc: 0.3110
# Epoch duration 0m 54s
#
# Epoch 9/9
# ----------
# training Loss: 2.1687 Acc: 0.2500
# validation Loss: 2.0602 Acc: 0.3839
# Epoch duration 0m 54s
#
# Training completed in 10m 21s
# Lowest validation loss: 2.050702

# %%
EvaluateOnData(ImageClassModel, "Dataset/test_labels.csv", "Dataset/test2")
# Out:
# Sample Image
# Accuracy of the model is: 32.2917 %

# %%
EvaluateOnData(ImageClassModel, "Dataset/real_labels.csv", "Dataset/Upload_Images")
# Out:
# Sample Image
# Accuracy of the model is: 0.0000 %

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
#
# NVIDIA GeForce GTX 1080
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.1 GB

# %%
# SaveCurrentModel("Dataset/Latest.pt")

# %%
# LoadLatestModel()
